# %% [markdown]
# <a href="https://colab.research.google.com/github/ArunMadavan/YouTube-Web-Crawler/blob/mainhttps%2Fgithub.com%2FArunBarry%2FMongoDB-Task/YouTube_Web_Crawler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# YOUTUBE WEB CRAWLER PROJECT

# %%
# !pip install googlesearch-python

# %%
import pandas as pd
import json
import requests

# %%
import requests
import json

API_KEY = 'AIzaSyA375b25N4ERwgl-RRs3iuy_WP6nEFgf48'

def get_youtube_channel_links(page_token=None):
    search_query = 'site:youtube.com openinapp.co'
    num_results = 10000
    youtube_links = []

    url = f'https://www.googleapis.com/youtube/v3/search?key={API_KEY}&q={search_query}&part=snippet&type=channel&maxResults={num_results}'

    if page_token:
        url += f'&pageToken={page_token}'

    response = requests.get(url)
    data = json.loads(response.text)

    for item in data['items']:
        channel_id = item['id']['channelId']
        youtube_links.append(f'https://www.youtube.com/channel/{channel_id}')

    if 'nextPageToken' in data:
        next_page_token = data['nextPageToken']
        youtube_links += get_youtube_channel_links(next_page_token)

    return youtube_links

def save_to_json(youtube_links):
    data = {'youtube_links': youtube_links}
    with open('youtube_channels.json', 'w') as outfile:
        json.dump(data, outfile, indent=4)

if __name__ == '__main__':
    youtube_links = get_youtube_channel_links()
    save_to_json(youtube_links)

# %%
import json
import pandas as pd

# Open the JSON file
with open('/content/youtube_channels.json', 'r') as file:
    # Load the entire JSON data
    json_data = json.load(file)

# Access the JSON data
print(json_data)
# Convert JSON to DataFrame
df = pd.DataFrame(json_data)

# Print the DataFrame
df
# Out:
# {'youtube_links': ['https://www.youtube.com/channel/UCIGDcUqL2kKMdJCpIr_dfxg', 'https://www.youtube.com/channel/UClSse6Ecr9J5M4UNdesvOFw', 'https://www.youtube.com/channel/UCp0sUXwGMU2ral7BLhqVlyQ', 'https://www.youtube.com/channel/UCBCJXoLxRDvQjHzvOljALtA', 'https://www.youtube.com/channel/UCiRIsMKRG4gE4SCySZASVLA', 'https://www.youtube.com/channel/UCRGjmePlgi3YRzHYvi-bu_g', 'https://www.youtube.com/channel/UCjgd9P6kXQzEeLrKJsppkfA', 'https://www.youtube.com/channel/UCuyQk-cFzUh0dkRn78gBL-g', 'https://www.youtube.com/channel/UCfY4j88EfKMBpjRXbfTh2hw', 'https://www.youtube.com/channel/UCozSKlObfMakw4Ff13FNLjw', 'https://www.youtube.com/channel/UCsg_lRB0twacbHtihbzKdBg', 'https://www.youtube.com/channel/UCF8sVugKEugdxCtok3qXtUg', 'https://www.youtube.com/channel/UCYjmZVwNxEfOKoPQwAxuxiw', 'https://www.youtube.com/channel/UC69aIkGI4AhfPogFMCzijLw', 'https://www.youtube.com/channel/UCe_WYj2PYAnSAwvTqMZku-A', 'https://www.youtube.com/channel/UCIURt4pvHlRJc8Es6dc0HdA', 'https://www.youtube.com/channel/UCLjaml8YliLtKsEZ6JRA5Qw', 'https://www.youtube.com/channel/UC9XQMbdkMwqttwhtT-XkE8Q', 'https://www.youtube.com/channel/UCMVPlhb-X3vgSmdf76o97yw', 'https://www.youtube.com/channel/UCBzfppvA5t7raHsa9m_qWXw', 'https://www.youtube.com/channel/UCUrzdwxo96B2ErFMsKsSzlw', 'https://www.youtube.com/channel/UCGdefOn-RgFuM1lQPXtiGFw', 'https://www.youtube.com/channel/UCcPJjQMhqzC7fGfGCENugfA', 'https://www.youtube.com/channel/UC-vplhxgsHsZ9QupdhuKrPg', 'https://www.youtube.com/channel/UCPheKdLCV2eUU6Zx_hPRI5Q', 'https://www.youtube.com/channel/UChXbuSuPVmFAE-qKtLUIpLA', 'https://www.youtube.com/channel/UCyKOHaJ4kz73emFupuQk8tw', 'https://www.youtube.com/channel/UCzgYRG3wF9HkYHCpxy9I5Dw', 'https://www.youtube.com/channel/UCVeD0s-c3Us-6ieAg71xHSQ', 'https://www.youtube.com/channel/UC4PuQWfEZsgj71tUI1cTZag', 'https://www.youtube.com/channel/UCHk8MqDR47SkgOOjdoqQclA', 'https://www.youtube.com/channel/UCj3jhrA7S9Q8XeOiJEuJHfQ', 'https://www.youtube.com/channel/UCkGBx3W2-8WSeDL-u_-1HoA', 'https://www.youtube.com/channel/UCP4fWOXwvsb45lLOvGnivDQ', 'https://www.youtube.com/channel/UCM_nbZv_AZwc35GBlSR1H8w', 'https://www.youtube.com/channel/UCZNvz8bsJ7giQacLumsUlGw', 'https://www.youtube.com/channel/UCk9oxXOzXVP5lf8arQ-0MQA', 'https://www.youtube.com/channel/UCAyBF6k9EaSaJ9u3JF8ofww', 'https://www.youtube.com/channel/UCSVV7v1Y7cU3Ziug0Vb79Zw', 'https://www.youtube.com/channel/UC1jg71BdbmSfZDUhmgEt9FQ', 'https://www.youtube.com/channel/UCH-ouesbQueqPaHQfOUjCCQ', 'https://www.youtube.com/channel/UCzEh8VZ-v3awYpOmNC870oQ', 'https://www.youtube.com/channel/UC9WjdtTcZv96NpInXw52ApQ', 'https://www.youtube.com/channel/UCi9LnEUk9LNVeHLcbaijoPQ', 'https://www.youtube.com/channel/UC5YeE3qYHByBhmZrPRfcWvg', 'https://www.youtube.com/channel/UCfcKEKeTVIKI3--NzqqoaIw', 'https://www.youtube.com/channel/UCNih_p6dHxACpXFutvigqUg', 'https://www.youtube.com/channel/UCcFvvK0IAWaNqyU8_Po5jBQ', 'https://www.youtube.com/channel/UCsrOW9xzek1lmYD9hdh--cg', 'https://www.youtube.com/channel/UCkB_xShz_Et60SUA82Djk_Q', 'https://www.youtube.com/channel/UC1ZIN3X3RJELUbfFx-F127Q', 'https://www.youtube.com/channel/UCRymAIn_O5COizGQVKJCEZA', 'https://www.youtube.com/channel/UC6GbBv0EyKoPc5VL-iBlktg', 'https://www.youtube.com/channel/UCJH7QJirjD95WnNVIqxZbEg', 'https://www.youtube.com/channel/UCiio3uKnlQZjRcB-zuOBTBg', 'https://www.youtube.com/channel/UCw4uiKru9QDiIVzXNt1C-OA', 'https://www.youtube.com/channel/UCPVhK6_gXEnZvI6ppUJR59Q', 'https://www.youtube.com/channel/UCDaU1hELX4ysN8Cyh9i9iTg', 'https://www.youtube.com/channel/UCyErc827n8eBLgqu_O26crg', 'https://www.youtube.com/channel/UCdQ2hg4ZxYDif20jJMvEvCg', 'https://www.youtube.com/channel/UCVtzC3W6w4LuNlvE0ETEG3w', 'https://www.youtube.com/channel/UCNMRDiqf_ry-N45u2vjM2sw', 'https://www.youtube.com/channel/UCK2HZOcoB1QpuoP7DiAaDmw', 'https://www.youtube.com/channel/UCEdB212oGIPOxmccu1ZnSDg', 'https://www.youtube.com/channel/UCwbkNAH62_rGBg7ahb7TXpw', 'https://www.youtube.com/channel/UClFxYHHykViVjthKmtlmi9w', 'https://www.youtube. ...
#                                          youtube_links
# 0    https://www.youtube.com/channel/UCIGDcUqL2kKMd...
# 1    https://www.youtube.com/channel/UClSse6Ecr9J5M...
# 2    https://www.youtube.com/channel/UCp0sUXwGMU2ra...
# 3    https://www.youtube.com/channel/UCBCJXoLxRDvQj...
# 4    https://www.youtube.com/channel/UCiRIsMKRG4gE4...
# ..                                                 ...
# 507  https://www.youtube.com/channel/UC5n7iTXs9j_U9...
# 508  https://www.youtube.com/channel/UCLNoocOzeUUWh...
# 509  https://www.youtube.com/channel/UCspflkpsLptae...
# 510  https://www.youtube.com/channel/UCVdzwHY_bYQLc...
# 511  https://www.youtube.com/channel/UCKokgXzj4JFVU...
#
# [512 rows x 1 columns]

# %%
import requests
import json

API_KEY = 'AIzaSyAq9jdrOF-vZX4f39VwHe1KGgvWTmDuQio'

def get_channel_info(channel_id):
    url = f'https://www.googleapis.com/youtube/v3/channels?key={API_KEY}&id={channel_id}&part=snippet,statistics'

    response = requests.get(url)
    data = json.loads(response.text)

    if 'items' in data and len(data['items']) > 0:
        item = data['items'][0]
        channel_name = item['snippet']['title']
        subscriber_count = int(item['statistics']['subscriberCount'])
        video_count = int(item['statistics']['videoCount'])
        view_count = int(item['statistics']['viewCount'])

        return {
            'Channel_name': channel_name,
            'Subscribers': subscriber_count,
            'Total_videos': video_count,
            'Views': view_count
        }

    return None

def load_from_json():
    with open('youtube_channels.json') as json_file:
        data = json.load(json_file)
        return data['youtube_links']

def get_channel_information(youtube_links):
    channel_info_list = []
    for link in youtube_links:
        channel_id = link.split('/')[-1]
        channel_info = get_channel_info(channel_id)
        if channel_info:
            channel_info_list.append(channel_info)

    return channel_info_list

def save_to_json(channel_info_list):
    data = {'channel_info': channel_info_list}
    with open('channel_information.json', 'w') as outfile:
        json.dump(data, outfile, indent=4)

if __name__ == '__main__':
    youtube_links = load_from_json()
    channel_info_list = get_channel_information(youtube_links)
    save_to_json(channel_info_list)

# %%
import pandas as pd
import json

def read_json_to_dataframe(json_file):
    with open(json_file) as file:
        data = json.load(file)
    channel_info = data['channel_info']
    df = pd.DataFrame(channel_info)
    return df

if __name__ == '__main__':
    json_file = '/content/channel_information.json'
    df = read_json_to_dataframe(json_file)
    

df
# Out:
#                           Channel_name  Subscribers  Total_videos      Views
# 0                            OpeninApp          671            53      82635
# 1                            ASIF OMAR       212000           454   16183703
# 2                   Illegal TravellerZ          558           139     178862
# 3                     Villain_Captures          219            44      15803
# 4                      Ride With Pride          632           221     168501
# ..                                 ...          ...           ...        ...
# 507                           Mr. Dugu          582            68     121778
# 508             It's Sahil Pagla Choda        45900            12    1066174
# 509  Bhakt Bhagwat GIVEGITA (Official)       184000           185   30699784
# 510                       funny videos          831             1          1
# 511                       aamhi_2_jawa       104000          1250  126287266
#
# [512 rows x 4 columns]

# %%
import requests
import json

API_KEY = 'AIzaSyAq9jdrOF-vZX4f39VwHe1KGgvWTmDuQio'

def get_channel_info(channel_id):
    url = f'https://www.googleapis.com/youtube/v3/channels?key={API_KEY}&id={channel_id}&part=snippet,statistics'

    response = requests.get(url)
    data = json.loads(response.text)

    if 'items' in data and len(data['items']) > 0:
        item = data['items'][0]
        channel_name = item['snippet']['title']
        description = item['snippet']['description']
        creation_date = item['snippet']['publishedAt']
        thumbnails = item['snippet']['thumbnails']
        subscriber_count = int(item['statistics']['subscriberCount'])
        video_count = int(item['statistics']['videoCount'])
        view_count = int(item['statistics']['viewCount'])
      

        return {
            'Channel_name': channel_name,
            'Description': description,
            'Creation_date': creation_date,
            'Thumbnails': thumbnails,
            'Subscribers': subscriber_count,
            'Total_videos': video_count,
            'Views': view_count,
           
        }

    return None
def load_from_json():
    with open('youtube_channels.json') as json_file:
        data = json.load(json_file)
        return data['youtube_links']

def get_channel_information(youtube_links):
    channel_info_list = []
    for link in youtube_links:
        channel_id = link.split('/')[-1]
        channel_info = get_channel_info(channel_id)
        if channel_info:
            channel_info_list.append(channel_info)

    return channel_info_list

def save_to_json(channel_info_list):
    data = {'channel_info': channel_info_list}
    with open('channels_information.json', 'w') as outfile:
        json.dump(data, outfile, indent=4)

if __name__ == '__main__':
    youtube_links = load_from_json()
    channel_info_list = get_channel_information(youtube_links)
    save_to_json(channel_info_list)

# %%
import pandas as pd
import json

def read_json_to_dataframe(json_file):
    with open(json_file) as file:
        data = json.load(file)
    channel_info = data['channel_info']
    df = pd.DataFrame(channel_info)
    return df

if __name__ == '__main__':
    json_file = '/content/channels_information.json'
    df3 = read_json_to_dataframe(json_file)
    

df3
# Out:
#                           Channel_name  \
# 0                            OpeninApp
# 1                            ASIF OMAR
# 2                   Illegal TravellerZ
# 3                     Villain_Captures
# 4                      Ride With Pride
# ..                                 ...
# 507                           Mr. Dugu
# 508             It's Sahil Pagla Choda
# 509  Bhakt Bhagwat GIVEGITA (Official)
# 510                       funny videos
# 511                       aamhi_2_jawa
#
#                                            Description  \
# 0    Boosting social and email campaign ROIs like c...
# 1    hai youtube..🙋🏻‍♂️\n\nmy name is : mohammed as...
# 2         Insta - @__vishu__thakur__\nhttps://IG.op...
# 3    Namaskara Karnataka!!   Welcome to my Channel!...
# 4    In this channel I am sharing my travel experie...
# ..                                                 ...
# 507  Welcome TO THE House OF entertainment ~~~~~~~~...
# 508                                     PARAR KAKIMA 🔥
# 509  This Youtube channel is the official channel o...
# 510  Hello friends\n दोस्तों में YouTube पर नया हूं...
# 511  नमस्कार मित्रांनो.मी शितल शिंदे स्वागत करते आप...
#
#                    Creation_date  \
# 0    2022-02-24T11:13:58.528238Z
# 1    2020-09-27T18:29:36.341113Z
# 2    2022-10-15T09:14:11.318007Z
# 3    2021-12-15T06:39:02.777826Z
# 4    2022-07-02T09:47:53.954524Z
# ..                           ...
# 507  2021-04-04T08:52:02.464106Z
# 508  2022-01-23T22:09:21.673154Z
# 509  2022-11-02T09:05:04.578594Z
# 510         2017-11-30T14:09:23Z
# 511         2019-06-19T11:49:07Z
#
#                                             Thumbnails  Subscribers  \
# 0    {'default': {'url': 'https://yt3.ggpht.com/-WV...          671
# 1    {'default': {'url': 'https://yt3.ggpht.com/oE0...       212000
# 2    {'default': {'url': 'https://yt3.ggpht.com/xZq...          558
# 3    {'default': {'url': 'https://yt3.ggpht.com/BSg...          219
# 4    {'default': {'url': 'https://yt3.ggpht.com/OXQ...          632
# ..                                                 ...          ...
# 507  {'default': {'url': 'https://yt3.ggpht.com/nP7...          582
# 508  {'default': {'url': 'https://yt3.ggpht.com/Toe...        45900
# 509  {'default': {'url': 'https://yt3.ggpht.com/DNG...       184000
# 510  {'default': {'url': 'https://yt3.ggpht.com/IUK...          831
# 511  {'default': {'url': 'https://yt3.ggpht.com/HFH...       104000
#
#      Total_videos      Views
# 0              53      82635
# 1             454   16183703
# 2             139     178862
# 3              44      15803
# 4             221     168501
# ..            ...        ...
# 507            68     121778
# 508            12    1066174
# 509           185   30699784
# 510             1          1
# 511          1250  126287266
#
# [512 rows x 7 columns]

# %%
df3['Creation_date'] = pd.to_datetime(df3['Creation_date']).dt.date
df3
# Out:
#                           Channel_name  \
# 0                            OpeninApp
# 1                            ASIF OMAR
# 2                   Illegal TravellerZ
# 3                     Villain_Captures
# 4                      Ride With Pride
# ..                                 ...
# 507                           Mr. Dugu
# 508             It's Sahil Pagla Choda
# 509  Bhakt Bhagwat GIVEGITA (Official)
# 510                       funny videos
# 511                       aamhi_2_jawa
#
#                                            Description Creation_date  \
# 0    Boosting social and email campaign ROIs like c...    2022-02-24
# 1    hai youtube..🙋🏻‍♂️\n\nmy name is : mohammed as...    2020-09-27
# 2         Insta - @__vishu__thakur__\nhttps://IG.op...    2022-10-15
# 3    Namaskara Karnataka!!   Welcome to my Channel!...    2021-12-15
# 4    In this channel I am sharing my travel experie...    2022-07-02
# ..                                                 ...           ...
# 507  Welcome TO THE House OF entertainment ~~~~~~~~...    2021-04-04
# 508                                     PARAR KAKIMA 🔥    2022-01-23
# 509  This Youtube channel is the official channel o...    2022-11-02
# 510  Hello friends\n दोस्तों में YouTube पर नया हूं...    2017-11-30
# 511  नमस्कार मित्रांनो.मी शितल शिंदे स्वागत करते आप...    2019-06-19
#
#                                             Thumbnails  Subscribers  \
# 0    {'default': {'url': 'https://yt3.ggpht.com/-WV...          671
# 1    {'default': {'url': 'https://yt3.ggpht.com/oE0...       212000
# 2    {'default': {'url': 'https://yt3.ggpht.com/xZq...          558
# 3    {'default': {'url': 'https://yt3.ggpht.com/BSg...          219
# 4    {'default': {'url': 'https://yt3.ggpht.com/OXQ...          632
# ..                                                 ...          ...
# 507  {'default': {'url': 'https://yt3.ggpht.com/nP7...          582
# 508  {'default': {'url': 'https://yt3.ggpht.com/Toe...        45900
# 509  {'default': {'url': 'https://yt3.ggpht.com/DNG...       184000
# 510  {'default': {'url': 'https://yt3.ggpht.com/IUK...          831
# 511  {'default': {'url': 'https://yt3.ggpht.com/HFH...       104000
#
#      Total_videos      Views
# 0              53      82635
# 1             454   16183703
# 2             139     178862
# 3              44      15803
# 4             221     168501
# ..            ...        ...
# 507            68     121778
# 508            12    1066174
# 509           185   30699784
# 510             1          1
# 511          1250  126287266
#
# [512 rows x 7 columns]

# %%
# save a Json file 
df3.to_json('youtube_channel_link.json', orient='records')

# %%
# Read json
df = pd.read_json('/content/youtube_channel_link.json')
df
# Out:
#                           Channel_name  \
# 0                            OpeninApp
# 1                            ASIF OMAR
# 2                   Illegal TravellerZ
# 3                     Villain_Captures
# 4                      Ride With Pride
# ..                                 ...
# 507                           Mr. Dugu
# 508             It's Sahil Pagla Choda
# 509  Bhakt Bhagwat GIVEGITA (Official)
# 510                       funny videos
# 511                       aamhi_2_jawa
#
#                                            Description  Creation_date  \
# 0    Boosting social and email campaign ROIs like c...  1645660800000
# 1    hai youtube..🙋🏻‍♂️\n\nmy name is : mohammed as...  1601164800000
# 2         Insta - @__vishu__thakur__\nhttps://IG.op...  1665792000000
# 3    Namaskara Karnataka!!   Welcome to my Channel!...  1639526400000
# 4    In this channel I am sharing my travel experie...  1656720000000
# ..                                                 ...            ...
# 507  Welcome TO THE House OF entertainment ~~~~~~~~...  1617494400000
# 508                                     PARAR KAKIMA 🔥  1642896000000
# 509  This Youtube channel is the official channel o...  1667347200000
# 510  Hello friends\n दोस्तों में YouTube पर नया हूं...  1512000000000
# 511  नमस्कार मित्रांनो.मी शितल शिंदे स्वागत करते आप...  1560902400000
#
#                                             Thumbnails  Subscribers  \
# 0    {'default': {'url': 'https://yt3.ggpht.com/-WV...          671
# 1    {'default': {'url': 'https://yt3.ggpht.com/oE0...       212000
# 2    {'default': {'url': 'https://yt3.ggpht.com/xZq...          558
# 3    {'default': {'url': 'https://yt3.ggpht.com/BSg...          219
# 4    {'default': {'url': 'https://yt3.ggpht.com/OXQ...          632
# ..                                                 ...          ...
# 507  {'default': {'url': 'https://yt3.ggpht.com/nP7...          582
# 508  {'default': {'url': 'https://yt3.ggpht.com/Toe...        45900
# 509  {'default': {'url': 'https://yt3.ggpht.com/DNG...       184000
# 510  {'default': {'url': 'https://yt3.ggpht.com/IUK...          831
# 511  {'default': {'url': 'https://yt3.ggpht.com/HFH...       104000
#
#      Total_videos      Views
# 0              53      82635
# 1             454   16183703
# 2             139     178862
# 3              44      15803
# 4             221     168501
# ..            ...        ...
# 507            68     121778
# 508            12    1066174
# 509           185   30699784
# 510             1          1
# 511          1250  126287266
#
# [512 rows x 7 columns]
